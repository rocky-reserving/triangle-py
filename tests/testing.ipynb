# %%
import sys
sys.path.append("..")
sys.path.append("../..")
sys.path.append("../triangle_py/")

# %%
import pandas as pd
import numpy as np
from triangle_py.triangle import Triangle
# def test_triangle():
#     df = pd.DataFrame({
#         '12':[10, 10, 10, 10],
#         '24':[20, 20, 20, np.nan],
#         '36':[30, 30, np.nan, np.nan],
#         '48':[40, np.nan, np.nan, np.nan]
#     }, index=[2000, 2001, 2002, 2003])
#     return Triangle.from_dataframe(df=df, id="t")
# def test_triangle2():
#     df = pd.DataFrame({
#         '12':[10, 11, 12, 13],
#         '24':[20, 30, 40, np.nan],
#         '36':[30, 37, np.nan, np.nan],
#         '48':[40, np.nan, np.nan, np.nan]
#     }, index=[2000, 2001, 2002, 2003])
#     return Triangle.from_dataframe(df=df, id="t")

# t = test_triangle()
# t2 = test_triangle2()

# %%
# !pytest test_triangle.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.3, pytest-7.4.0, pluggy-1.2.0
# rootdir: /home/aweaver/git/Triangle/tests
# collected 38 items
#
# test_triangle.py ..................................FFF.                  [100%]
#
# =================================== FAILURES ===================================
# ______________________ test_create_design_matrix_trends1 _______________________
#
# test_triangle = development_period    12    24    36    48
# accident_period
# 2000-01-01          10.0  20.0  ...1          10.0  20.0  30.0   NaN
# 2002-01-01          10.0  20.0   NaN   NaN
# 2003-01-01          10.0   NaN   NaN   NaN
# test_dm_ay_trends =     accident_period  ...  accident_period_2003
# 0              2000  ...                     0
# 1              2001  ...... 0
# 14             2002  ...                     0
# 15             2003  ...                     1
#
# [16 rows x 4 columns]
#
#     def test_create_design_matrix_trends1(test_triangle, test_dm_ay_trends):
#         t = test_triangle
#         expected_df = test_dm_ay_trends
#         print(f"expected_df: {expected_df}")
#         print(f"expected_df.shape: {expected_df.shape}")
#
#         # get the design matrix from the triangle object
#         df = t.create_design_matrix_trends(t.X_id['accident_period'], z=4, s="accident_period")
#         print(f"df: {df}")
#         print(f"df.shape: {df.shape}")
#
#         # make sure the design matrix is the same as the expected design matrix
# >       assert are_dfs_equal(df,expected_df), f"""TRI-043-A -
#         Triangle.create_design_matrix_trends did not return the same design matrix as expected:
#         df: {df}
#         expected_df: {expected_df}"""
# E       AssertionError: TRI-043-A -
# E             Triangle.create_design_matrix_trends did not return the same design matrix as expected:
# E             df:     accident_period  ...  accident_period_2003
# E         0              2000  ...                     0
# E         1              2001  ...                     0
# E         2              2002  ...                     0
# E         3              2003  ...                     1
# E         4              2000  ...                     0
# E         5              2001  ...                     0
# E         6              2002  ...                     0
# E         7              2003  ...                     1
# E         8              2000  ...                     0
# E         9              2001  ...                     0
# E         10             2002  ...                     0
# E         11             2003  ...                     1
# E         12             2000  ...                     0
# E         13             2001  ...                     0
# E         14             2002  ...                     0
# E         15             2003  ...                     1
# E
# E         [16 rows x 4 columns]
# E             expected_df:     accident_period  ...  accident_period_2003
# E         0              2000  ...                     0
# E         1              2001  ...                     0
# E         2              2002  ...                     0
# E         3              2003  ...                     1
# E         4              2000  ...                     0
# E         5              2001  ...                     0
# E         6              2002  ...                     0
# E         7              2003  ...                     1
# E         8              2000  ...                     0
# E         9              2001  ...                     0
# E         10             2002  ...                     0
# E         11             2003  ...                     1
# E         12             2000  ...                     0
# E         13             2001  ...                     0
# E         14             2002  ...                     0
# E         15             2003  ...                     1
# E
# E         [16 rows x 4 columns]
# E       assert False
# E        +  where False = are_dfs_equal(    accident_period  ...  accident_period_2003\n0              2000  ...                     0\n1              2001  ...... 0\n14             2002  ...                     0\n15             2003  ...                     1\n\n[16 rows x 4 columns],     accident_period  ...  accident_period_2003\n0              2000  ...                     0\n1              2001  ...... 0\n14             2002  ...                     0\n15             2003  ...                     1\n\n[16 rows x 4 columns])
#
# test_triangle.py:694: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# expected_df:     accident_period  ...  accident_period_2003
# 0              2000  ...                     0
# 1              2001  ...                     0
# 2              2002  ...                     0
# 3              2003  ...                     1
# 4              2000  ...                     0
# 5              2001  ...                     0
# 6              2002  ...                     0
# 7              2003  ...                     1
# 8              2000  ...                     0
# 9              2001  ...                     0
# 10             2002  ...                     0
# 11             2003  ...                     1
# 12             2000  ...                     0
# 13             2001  ...                     0
# 14             2002  ...                     0
# 15             2003  ...                     1
#
# [16 rows x 4 columns]
# expected_df.shape: (16, 4)
# df:     accident_period  ...  accident_period_2003
# 0              2000  ...                     0
# 1              2001  ...                     0
# 2              2002  ...                     0
# 3              2003  ...                     1
# 4              2000  ...                     0
# 5              2001  ...                     0
# 6              2002  ...                     0
# 7              2003  ...                     1
# 8              2000  ...                     0
# 9              2001  ...                     0
# 10             2002  ...                     0
# 11             2003  ...                     1
# 12             2000  ...                     0
# 13             2001  ...                     0
# 14             2002  ...                     0
# 15             2003  ...                     1
#
# [16 rows x 4 columns]
# df.shape: (16, 4)
# ______________________ test_create_design_matrix_trends2 _______________________
#
# test_triangle = development_period    12    24    36    48
# accident_period
# 2000-01-01          10.0  20.0  ...1          10.0  20.0  30.0   NaN
# 2002-01-01          10.0  20.0   NaN   NaN
# 2003-01-01          10.0   NaN   NaN   NaN
# test_dm_ay_trends =     accident_period  ...  accident_period_2003
# 0              2000  ...                     0
# 1              2001  ...... 0
# 14             2002  ...                     0
# 15             2003  ...                     1
#
# [16 rows x 4 columns]
#
#     def test_create_design_matrix_trends2(test_triangle, test_dm_ay_trends):
#         t = test_triangle
#         expected_df = test_dm_ay_trends[['accident_period_2001']]
#         print(f"expected_df: {expected_df}")
#         print(f"expected_df.shape: {expected_df.shape}")
#
#         # get the design matrix from the triangle object
#         df = t.create_design_matrix_trends(t.X_id['accident_period'], z=4, s="accident_period")[['accident_period_2001']]
#         print(f"df: {df}")
#         print(f"df.shape: {df.shape}")
#
#         # make sure the design matrix is the same as the expected design matrix
# >       assert are_dfs_equal(df,expected_df), f"""TRI-043-B -
#         Triangle.create_design_matrix_trends did not return the same design matrix as expected:
#         df: {df}
#         expected_df: {expected_df}"""
# E       AssertionError: TRI-043-B -
# E             Triangle.create_design_matrix_trends did not return the same design matrix as expected:
# E             df:     accident_period_2001
# E         0                      0
# E         1                      0
# E         2                      1
# E         3                      1
# E         4                      0
# E         5                      0
# E         6                      1
# E         7                      1
# E         8                      0
# E         9                      0
# E         10                     1
# E         11                     1
# E         12                     0
# E         13                     0
# E         14                     1
# E         15                     1
# E             expected_df:     accident_period_2001
# E         0                      0
# E         1                      1
# E         2                      1
# E         3                      1
# E         4                      0
# E         5                      1
# E         6                      1
# E         7                      1
# E         8                      0
# E         9                      1
# E         10                     1
# E         11                     1
# E         12                     0
# E         13                     1
# E         14                     1
# E         15                     1
# E       assert False
# E        +  where False = are_dfs_equal(    accident_period_2001\n0                      0\n1                      0\n2                      1\n3                 ...                  1\n12                     0\n13                     0\n14                     1\n15                     1,     accident_period_2001\n0                      0\n1                      1\n2                      1\n3                 ...                  1\n12                     0\n13                     1\n14                     1\n15                     1)
#
# test_triangle.py:712: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# expected_df:     accident_period_2001
# 0                      0
# 1                      1
# 2                      1
# 3                      1
# 4                      0
# 5                      1
# 6                      1
# 7                      1
# 8                      0
# 9                      1
# 10                     1
# 11                     1
# 12                     0
# 13                     1
# 14                     1
# 15                     1
# expected_df.shape: (16, 1)
# df:     accident_period_2001
# 0                      0
# 1                      0
# 2                      1
# 3                      1
# 4                      0
# 5                      0
# 6                      1
# 7                      1
# 8                      0
# 9                      0
# 10                     1
# 11                     1
# 12                     0
# 13                     0
# 14                     1
# 15                     1
# df.shape: (16, 1)
# ______________________ test_create_design_matrix_trends3 _______________________
#
# test_triangle = development_period    12    24    36    48
# accident_period
# 2000-01-01          10.0  20.0  ...1          10.0  20.0  30.0   NaN
# 2002-01-01          10.0  20.0   NaN   NaN
# 2003-01-01          10.0   NaN   NaN   NaN
# test_dm_ay_trends =     accident_period  ...  accident_period_2003
# 0              2000  ...                     0
# 1              2001  ...... 0
# 14             2002  ...                     0
# 15             2003  ...                     1
#
# [16 rows x 4 columns]
#
#     def test_create_design_matrix_trends3(test_triangle, test_dm_ay_trends):
#         t = test_triangle
#         expected_df = test_dm_ay_trends[['accident_period_2002']]
#         print(f"expected_df: {expected_df}")
#         print(f"expected_df.shape: {expected_df.shape}")
#
#         # get the design matrix from the triangle object
#         df = t.create_design_matrix_trends(t.X_id['accident_period'], z=4, s="accident_period")[['accident_period_2002']]
#         print(f"df: {df}")
#         print(f"df.shape: {df.shape}")
#
#         # make sure the design matrix is the same as the expected design matrix
# >       assert are_dfs_equal(df,expected_df), f"""TRI-043-C -
#         Triangle.create_design_matrix_trends did not return the same design matrix as expected:
#         df: {df}
#         expected_df: {expected_df}"""
# E       AssertionError: TRI-043-C -
# E             Triangle.create_design_matrix_trends did not return the same design matrix as expected:
# E             df:     accident_period_2002
# E         0                      0
# E         1                      0
# E         2                      0
# E         3                      1
# E         4                      0
# E         5                      0
# E         6                      0
# E         7                      1
# E         8                      0
# E         9                      0
# E         10                     0
# E         11                     1
# E         12                     0
# E         13                     0
# E         14                     0
# E         15                     1
# E             expected_df:     accident_period_2002
# E         0                      0
# E         1                      0
# E         2                      1
# E         3                      1
# E         4                      0
# E         5                      0
# E         6                      1
# E         7                      1
# E         8                      0
# E         9                      0
# E         10                     1
# E         11                     1
# E         12                     0
# E         13                     0
# E         14                     1
# E         15                     1
# E       assert False
# E        +  where False = are_dfs_equal(    accident_period_2002\n0                      0\n1                      0\n2                      0\n3                 ...                  1\n12                     0\n13                     0\n14                     0\n15                     1,     accident_period_2002\n0                      0\n1                      0\n2                      1\n3                 ...                  1\n12                     0\n13                     0\n14                     1\n15                     1)
#
# test_triangle.py:729: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# expected_df:     accident_period_2002
# 0                      0
# 1                      0
# 2                      1
# 3                      1
# 4                      0
# 5                      0
# 6                      1
# 7                      1
# 8                      0
# 9                      0
# 10                     1
# 11                     1
# 12                     0
# 13                     0
# 14                     1
# 15                     1
# expected_df.shape: (16, 1)
# df:     accident_period_2002
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      0
# 5                      0
# 6                      0
# 7                      1
# 8                      0
# 9                      0
# 10                     0
# 11                     1
# 12                     0
# 13                     0
# 14                     0
# 15                     1
# df.shape: (16, 1)
# =========================== short test summary info ============================
# FAILED test_triangle.py::test_create_design_matrix_trends1 - AssertionError: TRI-043-A -
# FAILED test_triangle.py::test_create_design_matrix_trends2 - AssertionError: TRI-043-B -
# FAILED test_triangle.py::test_create_design_matrix_trends3 - AssertionError: TRI-043-C -
# ========================= 3 failed, 35 passed in 6.25s =========================
