# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../')
from triangle_py.triangle import Triangle

# %%
t = Triangle.from_taylor_ashe()
t.df
# Out:
# development_period         1          2          3          4          5  \
# accident_period
# 2001-01-01          357848.0  1124788.0  1735330.0  2218270.0  2745596.0
# 2002-01-01          352118.0  1236139.0  2170033.0  3353322.0  3799067.0
# 2003-01-01          290507.0  1292306.0  2218525.0  3235179.0  3985995.0
# 2004-01-01          310608.0  1418858.0  2195047.0  3757447.0  4029929.0
# 2005-01-01          443160.0  1136350.0  2128333.0  2897821.0  3402672.0
# 2006-01-01          396132.0  1333217.0  2180715.0  2985752.0  3691712.0
# 2007-01-01          440832.0  1288463.0  2419861.0  3483130.0        NaN
# 2008-01-01          359480.0  1421128.0  2864498.0        NaN        NaN
# 2009-01-01          376686.0  1363294.0        NaN        NaN        NaN
# 2010-01-01          344014.0        NaN        NaN        NaN        NaN
#
# development_period          6          7          8          9         10
# accident_period
# ...

# %%
t.use_cal
# Out:
# False

# %%
t.X_base.shape
# Out:
# (100, 21)

# %%
t.X_base_train.shape
# Out:
# (55, 21)

# %%
t.X_base_forecast.shape
# Out:
# (45, 21)

# %%
t.get_X()
# Out:
#     is_observed  intercept  accident_period_2002  accident_period_2003  \
# 0             1          1                     0                     0
# 1             1          1                     1                     0
# 2             1          1                     0                     1
# 3             1          1                     0                     0
# 4             1          1                     0                     0
# ..          ...        ...                   ...                   ...
# 95            0          1                     0                     0
# 96            0          1                     0                     0
# 97            0          1                     0                     0
# 98            0          1                     0                     0
# 99            0          1                     0                     0
#
#     accident_period_2004  accident_period_2005  accident_period_2006  \
# ...

# %%
t.X_id
# Out:
#          tri  is_observed  accident_period  development_period  \
# 0   357848.0            1             2001                   1
# 1   352118.0            1             2002                   1
# 2   290507.0            1             2003                   1
# 3   310608.0            1             2004                   1
# 4   443160.0            1             2005                   1
# ..       ...          ...              ...                 ...
# 95       NaN            0             2006                  10
# 96       NaN            0             2007                  10
# 97       NaN            0             2008                  10
# 98       NaN            0             2009                  10
# 99       NaN            0             2010                  10
#
#     calendar_period
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ..              ...
# 95               15
# 96               16
# ...
